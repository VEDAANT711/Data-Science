# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.rand(10)
# Out:
# array([0.11821598, 0.56324644, 0.62680732, 0.74101793, 0.22805931,
#        0.17987735, 0.07481283, 0.83334877, 0.6216479 , 0.20272594])

# %%
np.random.rand(20)
# Out:
# array([0.34786382, 0.86990955, 0.29584602, 0.84397283, 0.95684278,
#        0.89746275, 0.43883665, 0.39824288, 0.30942013, 0.63061194,
#        0.4505174 , 0.4204915 , 0.98430382, 0.53624258, 0.21798525,
#        0.42681455, 0.56112655, 0.93944974, 0.1596709 , 0.75052111])

# %%
np.random.rand(20)*10
# Out:
# array([3.78210318, 5.50546821, 6.92932012, 5.45763355, 4.31460427,
#        0.87902428, 2.38652048, 9.15034038, 5.14793684, 4.88053639,
#        5.51932907, 7.11791358, 4.87945373, 5.05204885, 1.23864259,
#        6.47368564, 3.83589345, 0.32689873, 3.34660817, 4.2389601 ])

# %%
np.random.rand(10)*20
# Out:
# array([ 4.76614545, 13.35270601, 17.00679624,  8.78333053,  4.80933511,
#         0.91836768, 11.1879745 ,  4.53733686, 15.99651638,  6.712401  ])

# %%
np.random.rand(20)*10
# Out:
# array([2.24285363, 7.96864713, 3.46266453, 2.97287809, 3.55600106,
#        0.70745367, 1.31954436, 1.00517385, 9.56063489, 6.36967791,
#        9.0375387 , 5.35865061, 1.51489876, 7.05539044, 3.37629241,
#        3.83550328, 2.54509752, 1.68007071, 4.71789505, 0.29755035])

# %%
x = np.arange(20)
y = np.linspace(1,20,20) + np.random.rand(20)*10
plt.scatter(x,y)
plt.show()

# %%
x = np.arange(20)
y = np.linspace(1,20,20) + np.random.rand(20)*10
plt.scatter(x,y)
plt.show()

# %%
x = np.arange(20)
y1 = np.linspace(1,20,20)+np.random.rand(20)*10
y2 = np.linspace(1,20,20)+np.random.rand(20)*110
plt.scatter(x,y1)
plt.scatter(x,y2)
plt.show()

# %%
x = np.arange(20)
y1 = np.linspace(1,20,20)+np.random.rand(20)*10
y2 = np.linspace(1,20,20)+np.random.rand(20)*110
plt.scatter(x,y1)
plt.scatter(x,y2)
plt.show()

# %%
x = np.arange(1,10,.1)
y = np.sin(x)
plt.plot(x,y)
plt.show()

# %%
x = np.arange(1,10,.1)
y = np.tan(x)
plt.plot(x,y)
plt.show()

# %%
x = np.arange(1,10,.1)
y1 = np.sin(x)
plt.plot(x,y1)

y2 = np.tan(x)
plt.plot(x,y2)
plt.show()

# %%
x = np.arange(1,10,.1)
y1 = np.sin(x)
y2 = np.tan(x)

plt.plot(x,y1)
plt.plot(x,y2)
plt.show()

# %%
x = np.arange(1,10,.1)
y1 = np.tan(x)
y2 = np.sin(x)
y3 = np.cos(x)


fig , ax = plt.subplots(1,3)
ax[0].plot(x,y1)
ax[1].plot(x,y2)
ax[2].plot(x,y3)

# %%
fig , ax = plt.subplots(1,3)

# %%
type(plt.subplots(1,3))
# Out:
# tuple

# %%
tup1 = (100,200,300)
print(tup1[0])
print(tup1[1])
print(tup1[2])
# Out:
# 100
# 200
# 300

# %%
a,b,c = tup1
print(a,b,c)
# Out:
# 100 200 300

# %%
plt.subplots(3,1)
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E28E8466C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E28EB04648>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E28E71F908>],
#        dtype=object))
