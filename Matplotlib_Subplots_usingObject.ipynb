# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
x = np.arange(1,10,.1)
y = np.sin(x)
y1 = np.tan(x)
y2 = np.cos(x)


fig,ax = plt.subplots(1,3)
ax[0].plot(x,y)
ax[1].plot(x,y1)
ax[2].plot(x,y2)

# %%
plt.subplots(1,3)
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A6482046C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A64821AB08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A64824EF48>],
#        dtype=object))

# %%
plt.subplots(1,5)
# Out:
# (<Figure size 432x288 with 5 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001A6482E3A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A648301048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A648336588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A648372048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001A6483A5B08>],
#        dtype=object))

# %%
plt.subplots(2,5)
# Out:
# (<Figure size 432x288 with 10 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A648429888>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A64846DF48>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A6484A77C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A6484E02C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A648515D48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x000001A64854F808>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A6485876C8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A6485BF988>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A6485F9B88>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x000001A648630E48>]],
#        dtype=object))

# %%
x = np.arange(1,10,.1)
y = np.sin(x)
y1 = np.tan(x)
y2 = np.cos(x)

plt.figure()
plt.subplot(3,1,1)
plt.plot(x,y)


plt.subplot(3,1,2)
plt.plot(x,y1)

plt.subplot(3,1,3)
plt.plot(x,y2)

# %%
x = np.arange(1,10,.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure()
plt.subplot(1,3,1)
plt.plot(x,y1)

plt.subplot(1,3,2)
plt.plot(x,y2)


plt.subplot(1,3,3)
plt.plot(x,y3)

# %%
x = np.arange(1,10,.1)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

plt.figure()
plt.subplot(2,3,1)
plt.plot(x,y1)

plt.subplot(2,3,2)
plt.plot(x,y2)


plt.subplot(2,3,3)
plt.plot(x,y3)


plt.subplot(2,3,4)
plt.plot()

plt.subplot(2,3,5)
plt.plot()

plt.subplot(2,3,6)
plt.plot()
# Out:
# []

# %% [markdown]
# # 3D PLotting

# %%
# a = np.arange(-1,1,0.005)
# b = a

# a ,b  = np.meshgrid(a,b)
# fig = plt.figure()
# ax = fig.add_subplot(projection='2d')
# ax.plot_surface(a,b,a**2+b**2)



import numpy as np
import matplotlib.pyplot as plt

# Create some sample data
a = np.linspace(-5, 5, 100)
b = np.linspace(-5, 5, 100)
a, b = np.meshgrid(a, b)

# Create a figure and specify a 3D subplot
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Plot the surface
ax.plot_surface(a, b, a**2 + b**2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(projection)
#      57     try:
# ---> 58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
#
# ~\anaconda3\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(self, name)
#      24         """
# ---> 25         return self._all_projection_types[name]
#      26
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-44c0616b6c03> in <module>
#      19 # Create a figure and specify a 3D subplot
#      20 fig = plt.figure()
# ---> 21 ax = fig.add_subplot(projection='3d')
#      22
#      23 # Plot the surface
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1394         else:
#    1395             projection_class, kwargs, key = \
# -> 1396                 self._process_projection_requirements(*args, **kwargs)
#    1397
#    1398             # try to find the axes with this key in the stack
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in _process_projection_requirements(self, polar, projection, *args, **kwargs)
#    1118
#    1119         if isinstance(projection, str) or projection is None:
# -> 1120             projection_class = projections.get_projection_class(projection)
#    1121         elif hasattr(projection, '_as_mpl_axes'):
#    1122             projection_class, extra_kwargs = projection._as_mpl_axes()
#
# ~\anaconda3\lib\site-packages\matplotlib\projections\__init__.py in get_projection_class(projection)
#      58         return projection_registry.get_projection_class(projection)
#      59     except KeyError:
# ---> 60         raise ValueError("Unknown projection %r" % projection)
#      61
#      62
#
# ValueError: Unknown projection '3d'
