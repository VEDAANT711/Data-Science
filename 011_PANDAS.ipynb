# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\ACER\OneDrive\Desktop\gapminder_full.csv')
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (1704, 6)

# %%
df['country']
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
df['year']
# Out:
# 0       1952
# 1       1957
# 2       1962
# 3       1967
# 4       1972
#         ...
# 1699    1987
# 1700    1992
# 1701    1997
# 1702    2002
# 1703    2007
# Name: year, Length: 1704, dtype: int64

# %%
df[['country','year']]
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
df[['country','gdp_cap']]
# Out:
#           country     gdp_cap
# 0     Afghanistan  779.445314
# 1     Afghanistan  820.853030
# 2     Afghanistan  853.100710
# 3     Afghanistan  836.197138
# 4     Afghanistan  739.981106
# ...           ...         ...
# 1699     Zimbabwe  706.157306
# 1700     Zimbabwe  693.420786
# 1701     Zimbabwe  792.449960
# 1702     Zimbabwe  672.038623
# 1703     Zimbabwe  469.709298
#
# [1704 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df[['country','gdp_cap','life_exp']]
# Out:
#           country     gdp_cap  life_exp
# 0     Afghanistan  779.445314    28.801
# 1     Afghanistan  820.853030    30.332
# 2     Afghanistan  853.100710    31.997
# 3     Afghanistan  836.197138    34.020
# 4     Afghanistan  739.981106    36.088
# ...           ...         ...       ...
# 1699     Zimbabwe  706.157306    62.351
# 1700     Zimbabwe  693.420786    60.377
# 1701     Zimbabwe  792.449960    46.809
# 1702     Zimbabwe  672.038623    39.989
# 1703     Zimbabwe  469.709298    43.487
#
# [1704 rows x 3 columns]

# %%
df.head(50)
# Out:
#         country  year  population continent  life_exp      gdp_cap
# 0   Afghanistan  1952     8425333      Asia    28.801   779.445314
# 1   Afghanistan  1957     9240934      Asia    30.332   820.853030
# 2   Afghanistan  1962    10267083      Asia    31.997   853.100710
# 3   Afghanistan  1967    11537966      Asia    34.020   836.197138
# 4   Afghanistan  1972    13079460      Asia    36.088   739.981106
# 5   Afghanistan  1977    14880372      Asia    38.438   786.113360
# 6   Afghanistan  1982    12881816      Asia    39.854   978.011439
# 7   Afghanistan  1987    13867957      Asia    40.822   852.395945
# 8   Afghanistan  1992    16317921      Asia    41.674   649.341395
# 9   Afghanistan  1997    22227415      Asia    41.763   635.341351
# 10  Afghanistan  2002    25268405      Asia    42.129   726.734055
# 11  Afghanistan  2007    31889923      Asia    43.828   974.580338
# 12      Albania  1952     1282697    Europe    55.230  1601.056136
# ...

# %%
df.tail(50)
# Out:
#                  country  year  population continent  life_exp      gdp_cap
# 1654             Vietnam  2002    80908147      Asia    73.017  1764.456677
# 1655             Vietnam  2007    85262356      Asia    74.249  2441.576404
# 1656  West Bank and Gaza  1952     1030585      Asia    43.160  1515.592329
# 1657  West Bank and Gaza  1957     1070439      Asia    45.671  1827.067742
# 1658  West Bank and Gaza  1962     1133134      Asia    48.127  2198.956312
# 1659  West Bank and Gaza  1967     1142636      Asia    51.631  2649.715007
# 1660  West Bank and Gaza  1972     1089572      Asia    56.532  3133.409277
# 1661  West Bank and Gaza  1977     1261091      Asia    60.765  3682.831494
# 1662  West Bank and Gaza  1982     1425876      Asia    64.406  4336.032082
# 1663  West Bank and Gaza  1987     1691210      Asia    67.046  5107.197384
# 1664  West Bank and Gaza  1992     2104779      Asia    69.718  6017.654756
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
#  3   continent   1704 non-null   object
#  4   life_exp    1704 non-null   float64
#  5   gdp_cap     1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
df.describe()
# Out:
#              year    population     life_exp        gdp_cap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %%
df.describe(include='all')
# Out:
#          country        year    population continent     life_exp  \
# count       1704  1704.00000  1.704000e+03      1704  1704.000000
# unique       142         NaN           NaN         5          NaN
# top     Tanzania         NaN           NaN    Africa          NaN
# freq          12         NaN           NaN       624          NaN
# mean         NaN  1979.50000  2.960121e+07       NaN    59.474439
# std          NaN    17.26533  1.061579e+08       NaN    12.917107
# min          NaN  1952.00000  6.001100e+04       NaN    23.599000
# 25%          NaN  1965.75000  2.793664e+06       NaN    48.198000
# 50%          NaN  1979.50000  7.023596e+06       NaN    60.712500
# 75%          NaN  1993.25000  1.958522e+07       NaN    70.845500
# max          NaN  2007.00000  1.318683e+09       NaN    82.603000
#
#               gdp_cap
# count     1704.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean      7215.327081
# std       9857.454543
# ...

# %%
df.describe(include='object')
# Out:
#          country continent
# count       1704      1704
# unique       142         5
# top     Tanzania    Africa
# freq          12       624

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
df['country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong, China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea, Dem. Rep.',
# ...

# %%
df['country'].value_counts()
# Out:
# Tanzania            12
# Sweden              12
# Hong Kong, China    12
# Slovenia            12
# Ireland             12
#                     ..
# Portugal            12
# Paraguay            12
# Madagascar          12
# Togo                12
# Serbia              12
# Name: country, Length: 142, dtype: int64

# %%
df['country'].value_counts().head(10)
# Out:
# Tanzania              12
# Sweden                12
# Hong Kong, China      12
# Slovenia              12
# Ireland               12
# Cote d'Ivoire         12
# Eritrea               12
# Lesotho               12
# West Bank and Gaza    12
# Equatorial Guinea     12
# Name: country, dtype: int64

# %%
##Adding Column

# %%
len(df.columns)
# Out:
# 6

# %%
df['gdp_cap']
# Out:
# 0       779.445314
# 1       820.853030
# 2       853.100710
# 3       836.197138
# 4       739.981106
#            ...
# 1699    706.157306
# 1700    693.420786
# 1701    792.449960
# 1702    672.038623
# 1703    469.709298
# Name: gdp_cap, Length: 1704, dtype: float64

# %%
df['happy_index'] = df['gdp_cap']*2

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#       happy_index
# 0     1558.890629
# 1     1641.706059
# 2     1706.201420
# 3     1672.394276
# 4     1479.962212
# ...           ...
# ...

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'continent', 'life_exp', 'gdp_cap',
#        'happy_index'],
#       dtype='object')

# %%
import numpy as np
import pandas as pd

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap  \
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
#       happy_index
# 0     1558.890629
# 1     1641.706059
# 2     1706.201420
# 3     1672.394276
# 4     1479.962212
# ...           ...
# ...

# %%
df.drop('happy_index',axis=1,inplace=True)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.rename({'year':'YEAR'},axis=1,inplace=True)

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
[i**2 for i in range(1,11)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
df['custom']= [i**2 for i in range(1,1705)]

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap   custom
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314        1
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030        4
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710        9
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138       16
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106       25
# ...           ...   ...         ...       ...       ...         ...      ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306  2890000
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786  2893401
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960  2896804
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623  2900209
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298  2903616
#
# [1704 rows x 7 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %% [markdown]
# # LOC & ILOC

# %%
ans = pd.Series([11,22,33,44],['a','b','c','d'])

# %%
ans
# Out:
# a    11
# b    22
# c    33
# d    44
# dtype: int64

# %%
type(ans)
# Out:
# pandas.core.series.Series

# %%
s = pd.Series(data=['a','b','c','d'])
s
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
s = pd.Series(['a','b','c'],[2,5,5])
s
# Out:
# 2    a
# 5    b
# 5    c
# dtype: object

# %%
s[5]
# Out:
# 5    b
# 5    c
# dtype: object

# %%
s
# Out:
# 2    a
# 5    b
# 5    c
# dtype: object

# %%
s[2]
# Out:
# 'a'

# %%
v= pd.Series(['a','b','c','d','e','f','g','h','i'],[1,1,2,2,3,3,4,4,5,])
v
# Out:
# 1    a
# 1    b
# 2    c
# 2    d
# 3    e
# 3    f
# 4    g
# 4    h
# 5    i
# dtype: object

# %%
v[1]
# Out:
# 1    a
# 1    b
# dtype: object

# %%
v[5]
# Out:
# 'i'

# %%
v
# Out:
# 1    a
# 1    b
# 2    c
# 2    d
# 3    e
# 3    f
# 4    g
# 4    h
# 5    i
# dtype: object

# %%
v[1:3]
# Out:
# 1    b
# 2    c
# dtype: object

# %%
v[0:3]
# Out:
# 1    a
# 1    b
# 2    c
# dtype: object

# %%
v.loc[1]          #explicit indexing > given by user
# Out:
# 1    a
# 1    b
# dtype: object

# %%
v.iloc[1]         #implicit indexing > by defauly by pandas
# Out:
# 'b'

# %%
v.loc[4]
# Out:
# 4    g
# 4    h
# dtype: object

# %%
v.iloc[::-1]
# Out:
# 5    i
# 4    h
# 4    g
# 3    f
# 3    e
# 2    d
# 2    c
# 1    b
# 1    a
# dtype: object

# %%
v.loc[1:2]
# Out:
# 1    a
# 1    b
# 2    c
# 2    d
# dtype: object

# %%
v.iloc[1:2]
# Out:
# 1    b
# dtype: object

# %% [markdown]
# # Pandas Rows

# %%
df.loc[0]
# Out:
# country       Afghanistan
# YEAR                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap           779.445
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# country       Afghanistan
# YEAR                 1952
# population        8425333
# continent            Asia
# life_exp           28.801
# gdp_cap           779.445
# Name: 0, dtype: object

# %%
df.head()
# Out:
#        country  YEAR  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[0:5]
# Out:
#        country  YEAR  population continent  life_exp     gdp_cap
# 0  Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1  Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2  Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3  Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4  Afghanistan  1972    13079460      Asia    36.088  739.981106

# %%
df.iloc[1000:1010]
# Out:
#          country  YEAR  population continent  life_exp      gdp_cap
# 1000    Mongolia  1972     1320500      Asia    53.754  1421.741975
# 1001    Mongolia  1977     1528000      Asia    55.491  1647.511665
# 1002    Mongolia  1982     1756032      Asia    57.489  2000.603139
# 1003    Mongolia  1987     2015133      Asia    60.222  2338.008304
# 1004    Mongolia  1992     2312802      Asia    61.271  1785.402016
# 1005    Mongolia  1997     2494803      Asia    63.625  1902.252100
# 1006    Mongolia  2002     2674234      Asia    65.033  2140.739323
# 1007    Mongolia  2007     2874127      Asia    66.803  3095.772271
# 1008  Montenegro  1952      413834    Europe    59.164  2647.585601
# 1009  Montenegro  1957      442829    Europe    61.448  3682.259903

# %%
df.iloc[0:1704:100]
# Out:
#                     country  YEAR  population continent  life_exp  \
# 0               Afghanistan  1952     8425333      Asia    28.801
# 100              Bangladesh  1972    70759295      Asia    45.252
# 200            Burkina Faso  1992     8878303    Africa    50.260
# 300                Colombia  1952    12350771  Americas    50.643
# 400          Czech Republic  1972     9862158    Europe    70.290
# 500                 Eritrea  1992     3668440    Africa    49.991
# 600               Guatemala  1952     3146381  Americas    42.023
# 700                   India  1972   567000000      Asia    50.651
# 800                   Japan  1992   124329269      Asia    79.360
# 900                   Libya  1952     1019729    Africa    42.723
# 1000               Mongolia  1972     1320500      Asia    53.754
# 1100            New Zealand  1992     3437674   Oceania    76.330
# 1200                   Peru  1952     8025700  Americas    43.902
# ...

# %%
df[::-1]
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# ...           ...   ...         ...       ...       ...         ...
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
#
# [1704 rows x 6 columns]

# %% [markdown]
# ADDING ROWS

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['country', 'YEAR', 'population', 'continent', 'life_exp', 'gdp_cap'], dtype='object')

# %%
d = {'country':'India', 'year':2020, 'population':1000000, 'continent':'Asia', 'life_exp':44.11, 'gdp_cap':101.1}

# %%
d
# Out:
# {'country': 'India',
#  'year': 2020,
#  'population': 1000000,
#  'continent': 'Asia',
#  'life_exp': 44.11,
#  'gdp_cap': 101.1}

# %%
df.append(d,ignore_index=True)
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap    year
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314     NaN
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030     NaN
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710     NaN
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138     NaN
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106     NaN
# ...           ...     ...         ...       ...       ...         ...     ...
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786     NaN
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960     NaN
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623     NaN
# 1703     Zimbabwe  2007.0    12311143    Africa    43.487  469.709298     NaN
# 1704        India     NaN     1000000      Asia    44.110  101.100000  2020.0
#
# [1705 rows x 7 columns]

# %%
df
# Out:
#           country  YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.iloc[1704] = pd.Series(d)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-109-7cfde8147bca> in <module>
# ----> 1 df.iloc[1704] = pd.Series(d)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     667         else:
#     668             key = com.apply_if_callable(key, self.obj)
# --> 669         indexer = self._get_setitem_indexer(key)
#     670         self._setitem_with_indexer(indexer, value)
#     671
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_setitem_indexer(self, key)
#     654         axis = self.axis or 0
#     655         try:
# --> 656             return self._convert_to_indexer(key, axis=axis)
#     657         except TypeError as e:
#     658
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, raise_missing)
#    2152
#    2153         try:
# ...

# %%
df.loc[1704] = pd.Series(d)

# %%
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007.0    12311143    Africa    43.487  469.709298
# 1704        India     NaN     1000000      Asia    44.110  101.100000
#
# [1705 rows x 6 columns]

# %%
d1 = {'country':'India', 'year':2024, 'population':1001000, 'continent':'Asia', 'life_exp':47.11, 'gdp_cap':105.1}
d1
# Out:
# {'country': 'India',
#  'year': 2024,
#  'population': 1001000,
#  'continent': 'Asia',
#  'life_exp': 47.11,
#  'gdp_cap': 105.1}

# %%
df.loc[1705] = pd.Series(d1)

# %%
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1703        India     NaN     1001000      Asia    47.110  105.100000
# 1704        India     NaN     1001000      Asia    47.110  105.100000
# 1705        India     NaN     1001000      Asia    47.110  105.100000
#
# [1706 rows x 6 columns]

# %% [markdown]
# REMOVNG DUPLICATES

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1701    False
# 1702    False
# 1703    False
# 1704     True
# 1705     True
# Length: 1706, dtype: bool

# %%
df[df.duplicated()]
# Out:
#      country  YEAR  population continent  life_exp  gdp_cap
# 1704   India   NaN     1001000      Asia     47.11    105.1
# 1705   India   NaN     1001000      Asia     47.11    105.1

# %%
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1703        India     NaN     1001000      Asia    47.110  105.100000
# 1704        India     NaN     1001000      Asia    47.110  105.100000
# 1705        India     NaN     1001000      Asia    47.110  105.100000
#
# [1706 rows x 6 columns]

# %%
df.loc[1706]= pd.Series(d1)

# %%
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1703        India     NaN     1001000      Asia    47.110  105.100000
# 1704        India     NaN     1001000      Asia    47.110  105.100000
# 1705        India     NaN     1001000      Asia    47.110  105.100000
# 1706        India     NaN     1001000      Asia    47.110  105.100000
#
# [1707 rows x 6 columns]

# %%
df.loc[1707]= pd.Series(d1)
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1703        India     NaN     1001000      Asia    47.110  105.100000
# 1704        India     NaN     1001000      Asia    47.110  105.100000
# 1705        India     NaN     1001000      Asia    47.110  105.100000
# 1706        India     NaN     1001000      Asia    47.110  105.100000
# 1707        India     NaN     1001000      Asia    47.110  105.100000
#
# [1708 rows x 6 columns]

# %%
df.drop_duplicates()
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987.0     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1703        India     NaN     1001000      Asia    47.110  105.100000
#
# [1704 rows x 6 columns]

# %%
df.drop_duplicates(keep='last',inplace=True)

# %%
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987.0     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1707        India     NaN     1001000      Asia    47.110  105.100000
#
# [1704 rows x 6 columns]

# %%
df.drop(2)
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# 5     Afghanistan  1977.0    14880372      Asia    38.438  786.113360
# ...           ...     ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987.0     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1707        India     NaN     1001000      Asia    47.110  105.100000
#
# [1703 rows x 6 columns]

# %%
df.drop(1707,axis=0)
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1698     Zimbabwe  1982.0     7636524    Africa    60.363  788.855041
# 1699     Zimbabwe  1987.0     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
#
# [1703 rows x 6 columns]

# %% [markdown]
# # 016_Pandas_Operations

# %%
df
# Out:
#           country    YEAR  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952.0     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957.0     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962.0    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967.0    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972.0    13079460      Asia    36.088  739.981106
# ...           ...     ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987.0     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992.0    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997.0    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002.0    11926563    Africa    39.989  672.038623
# 1707        India     NaN     1001000      Asia    47.110  105.100000
#
# [1704 rows x 6 columns]

# %%
df.describe()
# Out:
#               YEAR    population     life_exp        gdp_cap
# count  1703.000000  1.704000e+03  1704.000000    1704.000000
# mean   1979.483852  2.959457e+07    59.476566    7215.113109
# std      17.257525  1.061593e+08    12.914772    9857.605010
# min    1952.000000  6.001100e+04    23.599000     105.100000
# 25%    1964.500000  2.788354e+06    48.198000    1202.060309
# 50%    1977.000000  7.021053e+06    60.712500    3531.846989
# 75%    1992.000000  1.958522e+07    70.845500    9325.462346
# max    2007.000000  1.318683e+09    82.603000  113523.132900

# %%
df['life_exp']
# Out:
# 0       28.801
# 1       30.332
# 2       31.997
# 3       34.020
# 4       36.088
#          ...
# 1699    62.351
# 1700    60.377
# 1701    46.809
# 1702    39.989
# 1707    47.110
# Name: life_exp, Length: 1704, dtype: float64

# %%
df['life_exp'].min()
# Out:
# 23.599

# %%
df['life_exp'].max()
# Out:
# 82.603

# %%
df['life_exp'].mean()
# Out:
# 59.476565539906055

# %%
df['life_exp'].sum()
# Out:
# 101348.06768000001

# %%
df['life_exp'].count()
# Out:
# 1704

# %% [markdown]
# # 017_Pandas_Concat_Join_Merge

# %% [markdown]
# CONCAT

# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv(r'C:\Users\ACER\OneDrive\Desktop\a.csv')

# %%
a
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
b=pd.read_csv(r'C:\Users\ACER\OneDrive\Desktop\b.csv')

# %%
b
# Out:
#     A   C
# 0  10  20
# 1  30  40

# %%
pd.concat([a,b])
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
pd.concat([a,b],axis=0)
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
data = pd.concat([a,b],axis=1)

# %%
data
# Out:
#     A   B   A   C
# 0  10  20  10  20
# 1  30  40  30  40

# %%
data.iloc[:,1:3]
# Out:
#     B   A
# 0  20  10
# 1  40  30

# %% [markdown]
# JOIN

# %%
pd.concat([a,b],axis=1)
# Out:
#     A   B   A   C
# 0  10  20  10  20
# 1  30  40  30  40

# %%
pd.concat([a,b],join='outer')
# Out:
#     A     B     C
# 0  10  20.0   NaN
# 1  30  40.0   NaN
# 0  10   NaN  20.0
# 1  30   NaN  40.0

# %%
pd.concat([a,b],join='inner')
# Out:
#     A
# 0  10
# 1  30
# 0  10
# 1  30

# %% [markdown]
# MarkDown

# %%
a
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
b
# Out:
#     A   C
# 0  10  20
# 1  30  40

# %%
pd.merge(a,b)
# Out:
#     A   B   C
# 0  10  20  20
# 1  30  40  40

# %%
pd.merge(b,a)
# Out:
#     A   C   B
# 0  10  20  20
# 1  30  40  40

# %%
a.merge(b)
# Out:
#     A   B   C
# 0  10  20  20
# 1  30  40  40

# %%
b.merge(a)
# Out:
#     A   C   B
# 0  10  20  20
# 1  30  40  40

# %%
user = pd.DataFrame({'userid' : [1,2,3],'name' : ['A' ,'B' ,'C'] })
user
# Out:
#    userid name
# 0       1    A
# 1       2    B
# 2       3    C

# %%
msg = pd.DataFrame({'id':[1,1,2] ,'msg' : ['hello','bye','hi']})
msg
# Out:
#    id    msg
# 0   1  hello
# 1   1    bye
# 2   2     hi

# %%
user = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\user.csv")

# %%
user
# Out:
#    userid name
# 0       1    A
# 1       2    B
# 2       3    C

# %%
msg = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\msg.csv")

# %%
msg
# Out:
#    id    msg
# 0   1  hello
# 1   1    bye
# 2   2     hi

# %% [markdown]
# CONCAT

# %%
pd.concat([user,msg])
# Out:
#    userid name   id    msg
# 0     1.0    A  NaN    NaN
# 1     2.0    B  NaN    NaN
# 2     3.0    C  NaN    NaN
# 0     NaN  NaN  1.0  hello
# 1     NaN  NaN  1.0    bye
# 2     NaN  NaN  2.0     hi

# %%
pd.concat([msg,user])
# Out:
#     id    msg  userid name
# 0  1.0  hello     NaN  NaN
# 1  1.0    bye     NaN  NaN
# 2  2.0     hi     NaN  NaN
# 0  NaN    NaN     1.0    A
# 1  NaN    NaN     2.0    B
# 2  NaN    NaN     3.0    C

# %%
pd.concat([user,msg],axis=1)
# Out:
#    userid name  id    msg
# 0       1    A   1  hello
# 1       2    B   1    bye
# 2       3    C   2     hi

# %% [markdown]
# MERGE

# %%
msg.merge(user,left_on='id',right_on='userid')
# Out:
#    id    msg  userid name
# 0   1  hello       1    A
# 1   1    bye       1    A
# 2   2     hi       2    B

# %%
msg
# Out:
#    id    msg
# 0   1  hello
# 1   1    bye
# 2   2     hi

# %%
user
# Out:
#    userid name
# 0       1    A
# 1       2    B
# 2       3    C

# %%
msg.merge(user,left_on='id',right_on='userid',how='outer')
# Out:
#     id    msg  userid name
# 0  1.0  hello       1    A
# 1  1.0    bye       1    A
# 2  2.0     hi       2    B
# 3  NaN    NaN       3    C

# %%
msg.merge(user,left_on='id',right_on='userid',how='left')
# Out:
#    id    msg  userid name
# 0   1  hello       1    A
# 1   1    bye       1    A
# 2   2     hi       2    B

# %%
msg.merge(user,left_on='id',right_on='userid',how='right')
# Out:
#     id    msg  userid name
# 0  1.0  hello       1    A
# 1  1.0    bye       1    A
# 2  2.0     hi       2    B
# 3  NaN    NaN       3    C

# %%
msg.merge(user,left_on='id',right_on='userid',how='right').drop('id',axis=1)
# Out:
#      msg  userid name
# 0  hello       1    A
# 1    bye       1    A
# 2     hi       2    B
# 3    NaN       3    C

# %% [markdown]
# # STUDENT DATA

# %%
import numpy as pd

# %%
import pandas as pd

# %%
result = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\result.csv")
students = pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\students.csv")

# %%
result
# Out:
#     Unnamed: 0 seating no  Percentage Result   class
# 0            1       J301          59   Pass   third
# 1            2       J302          77   Pass   first
# 2            3       J303          89   Pass   first
# 3            4       J304          18   Fail    fail
# 4            5       J305          86   Pass   first
# 5            6       J306          50   Pass   third
# 6            7       J307          80   Pass   first
# 7            8       J308          50   Pass   third
# 8            9       J309          28   Fail    fail
# 9           10       J310          92   Pass   first
# 10          11       J311          24   Fail    fail
# 11          12       J312          74   Pass  second
# 12          13       J313          42   Pass   third
# 13          14       J314          42   Pass   third
# 14          15       J315          84   Pass   first
# 15          16       J316          40   Pass   third
# 16          17       J317          50   Pass   third
# ...

# %%
students
# Out:
#     sr no Roll no         name  class
# 0       1    J301      Aaditya      8
# 1       2    J302        Aarya      8
# 2       3    J303        Abhay      8
# 3       4    J304     Abhijeet      8
# 4       5    J305   Abhinandan      8
# ..    ...     ...          ...    ...
# 95     96    J396       Ujjwal      9
# 96     97    J397         Vasu      9
# 97     98    J398        Vidit      9
# 98     99    J399        Vijay      9
# 99    100    J400      Vishvas      9
#
# [100 rows x 4 columns]

# %%
result.shape
# Out:
# (20, 5)

# %%
students.shape
# Out:
# (100, 4)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20 non-null     int64
#  1   seating no  20 non-null     object
#  2   Percentage  20 non-null     int64
#  3   Result      20 non-null     object
#  4   class       20 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 928.0+ bytes

# %%
result.describe()
# Out:
#        Unnamed: 0  Percentage
# count    20.00000   20.000000
# mean     10.50000   57.900000
# std       5.91608   24.865745
# min       1.00000   18.000000
# 25%       5.75000   41.500000
# 50%      10.50000   54.500000
# 75%      15.25000   80.250000
# max      20.00000   92.000000

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sr no    100 non-null    int64
#  1   Roll no  100 non-null    object
#  2   name     100 non-null    object
#  3   class    100 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 3.2+ KB

# %%
students.describe()
# Out:
#             sr no       class
# count  100.000000  100.000000
# mean    50.500000    8.700000
# std     29.011492    0.460566
# min      1.000000    8.000000
# 25%     25.750000    8.000000
# 50%     50.500000    9.000000
# 75%     75.250000    9.000000
# max    100.000000    9.000000

# %%
students['Roll no']
# Out:
# 0     J301
# 1     J302
# 2     J303
# 3     J304
# 4     J305
#       ...
# 95    J396
# 96    J397
# 97    J398
# 98    J399
# 99    J400
# Name: Roll no, Length: 100, dtype: object

# %%
result['seating no']
# Out:
# 0     J301
# 1     J302
# 2     J303
# 3     J304
# 4     J305
# 5     J306
# 6     J307
# 7     J308
# 8     J309
# 9     J310
# 10    J311
# 11    J312
# 12    J313
# 13    J314
# 14    J315
# 15    J316
# 16    J317
# 17    J318
# 18    J319
# 19    J320
# Name: seating no, dtype: object

# %%
result['seating no'].isin(students['Roll no'])
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# Name: seating no, dtype: bool

# %%
result.iloc[:,1]
# Out:
# 0     J301
# 1     J302
# 2     J303
# 3     J304
# 4     J305
# 5     J306
# 6     J307
# 7     J308
# 8     J309
# 9     J310
# 10    J311
# 11    J312
# 12    J313
# 13    J314
# 14    J315
# 15    J316
# 16    J317
# 17    J318
# 18    J319
# 19    J320
# Name: seating no, dtype: object

# %%
students.columns
# Out:
# Index(['sr no', 'Roll no', 'name', 'class'], dtype='object')

# %%
result.columns
# Out:
# Index(['Unnamed: 0', 'seating no', 'Percentage', 'Result', 'class'], dtype='object')

# %%
result.merge(students,left_on='seating no',right_on='Roll no',how='inner')
# Out:
#     Unnamed: 0 seating no  Percentage Result class_x  sr no Roll no  \
# 0            1       J301          59   Pass   third      1    J301
# 1            2       J302          77   Pass   first      2    J302
# 2            3       J303          89   Pass   first      3    J303
# 3            4       J304          18   Fail    fail      4    J304
# 4            5       J305          86   Pass   first      5    J305
# 5            6       J306          50   Pass   third      6    J306
# 6            7       J307          80   Pass   first      7    J307
# 7            8       J308          50   Pass   third      8    J308
# 8            9       J309          28   Fail    fail      9    J309
# 9           10       J310          92   Pass   first     10    J310
# 10          11       J311          24   Fail    fail     11    J311
# 11          12       J312          74   Pass  second     12    J312
# 12          13       J313          42   Pass   third     13    J313
# ...

# %%
result.merge(students,left_on='seating no',right_on='Roll no',how='inner').drop('Unnamed: 0',axis=1)
# Out:
#    seating no  Percentage Result class_x  sr no Roll no         name  class_y
# 0        J301          59   Pass   third      1    J301      Aaditya        8
# 1        J302          77   Pass   first      2    J302        Aarya        8
# 2        J303          89   Pass   first      3    J303        Abhay        8
# 3        J304          18   Fail    fail      4    J304     Abhijeet        8
# 4        J305          86   Pass   first      5    J305   Abhinandan        8
# 5        J306          50   Pass   third      6    J306      Abhinay        8
# 6        J307          80   Pass   first      7    J307     Abhishek        8
# 7        J308          50   Pass   third      8    J308     Abimanyu        8
# 8        J309          28   Fail    fail      9    J309       Aditya        8
# 9        J310          92   Pass   first     10    J310        Akhil        8
# 10       J311          24   Fail    fail     11    J311       Akshat        8
# ...

# %%
result.merge(students,left_on='seating no',right_on='Roll no',how='inner').drop(['Unnamed: 0','seating no','class_x'],axis=1)
# Out:
#     Percentage Result  sr no Roll no         name  class_y
# 0           59   Pass      1    J301      Aaditya        8
# 1           77   Pass      2    J302        Aarya        8
# 2           89   Pass      3    J303        Abhay        8
# 3           18   Fail      4    J304     Abhijeet        8
# 4           86   Pass      5    J305   Abhinandan        8
# 5           50   Pass      6    J306      Abhinay        8
# 6           80   Pass      7    J307     Abhishek        8
# 7           50   Pass      8    J308     Abimanyu        8
# 8           28   Fail      9    J309       Aditya        8
# 9           92   Pass     10    J310        Akhil        8
# 10          24   Fail     11    J311       Akshat        8
# 11          74   Pass     12    J312         Anil        8
# 12          42   Pass     13    J313          Avi        8
# 13          42   Pass     14    J314     Balaraam        8
# 14          84   Pass     15    J315       Bharat        8
# ...
