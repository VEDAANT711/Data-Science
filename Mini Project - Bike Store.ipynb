# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r"C:\Users\ACER\OneDrive\Desktop\DATA\BikeStores.csv")

# %%
df
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28-11-2018
# 4718      1614      Dorthey Jackson     Houston    TX  28-11-2018
# 4719      1615         Sarita Parks      Forney    TX  28-12-2018
# 4720      1615         Sarita Parks      Forney    TX  28-12-2018
# 4721      1615         Sarita Parks      Forney    TX  28-12-2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'customers', 'city', 'state', 'order_date', 'total_units',
#        'revenue', 'product_name', 'category_name', 'brand_name', 'store_name',
#        'sales_rep'],
#       dtype='object')

# %%
df.shape
# Out:
# (4722, 12)

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       4722 non-null   int64
#  1   customers      4722 non-null   object
#  2   city           4722 non-null   object
#  3   state          4722 non-null   object
#  4   order_date     4722 non-null   object
#  5   total_units    4722 non-null   int64
#  6   revenue        4722 non-null   float64
#  7   product_name   4722 non-null   object
#  8   category_name  4722 non-null   object
#  9   brand_name     4722 non-null   object
#  10  store_name     4722 non-null   object
#  11  sales_rep      4722 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 442.8+ KB

# %%
df.describe()
# Out:
#           order_id  total_units       revenue
# count  4722.000000  4722.000000   4722.000000
# mean    821.265354     1.498941   1816.812554
# std     465.152168     0.500052   2228.160984
# min       1.000000     1.000000     89.990000
# 25%     423.250000     1.000000    539.980000
# 50%     828.500000     1.000000    939.980000
# 75%    1226.000000     2.000000   1999.980000
# max    1615.000000     2.000000  23999.980000

# %%
df[['customers','city','brand_name']]
# Out:
#                 customers        city brand_name
# 0     Johnathan Velazquez  Pleasanton    Electra
# 1     Johnathan Velazquez  Pleasanton    Electra
# 2     Johnathan Velazquez  Pleasanton      Surly
# 3     Johnathan Velazquez  Pleasanton       Trek
# 4     Johnathan Velazquez  Pleasanton       Trek
# ...                   ...         ...        ...
# 4717      Dorthey Jackson     Houston      Surly
# 4718      Dorthey Jackson     Houston       Trek
# 4719         Sarita Parks      Forney    Electra
# 4720         Sarita Parks      Forney       Trek
# 4721         Sarita Parks      Forney       Trek
#
# [4722 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# order_id                                            1
# customers                         Johnathan Velazquez
# city                                       Pleasanton
# state                                              CA
# order_date                                   1-1-2016
# total_units                                         2
# revenue                                       1199.98
# product_name     Electra Townie Original 7D EQ - 2016
# category_name                       Cruisers Bicycles
# brand_name                                    Electra
# store_name                           Santa Cruz Bikes
# sales_rep                             Mireya Copeland
# Name: 0, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4722 entries, 0 to 4721
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       4722 non-null   int64
#  1   customers      4722 non-null   object
#  2   city           4722 non-null   object
#  3   state          4722 non-null   object
#  4   order_date     4722 non-null   object
#  5   total_units    4722 non-null   int64
#  6   revenue        4722 non-null   float64
#  7   product_name   4722 non-null   object
#  8   category_name  4722 non-null   object
#  9   brand_name     4722 non-null   object
#  10  store_name     4722 non-null   object
#  11  sales_rep      4722 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 442.8+ KB

# %%
df.describe()
# Out:
#           order_id  total_units       revenue
# count  4722.000000  4722.000000   4722.000000
# mean    821.265354     1.498941   1816.812554
# std     465.152168     0.500052   2228.160984
# min       1.000000     1.000000     89.990000
# 25%     423.250000     1.000000    539.980000
# 50%     828.500000     1.000000    939.980000
# 75%    1226.000000     2.000000   1999.980000
# max    1615.000000     2.000000  23999.980000

# %%
df.head()
# Out:
#    order_id            customers        city state order_date  total_units  \
# 0         1  Johnathan Velazquez  Pleasanton    CA   1-1-2016            2
# 1         1  Johnathan Velazquez  Pleasanton    CA   1-1-2016            1
# 2         1  Johnathan Velazquez  Pleasanton    CA   1-1-2016            2
# 3         1  Johnathan Velazquez  Pleasanton    CA   1-1-2016            1
# 4         1  Johnathan Velazquez  Pleasanton    CA   1-1-2016            2
#
#    revenue                                    product_name  \
# 0  1199.98            Electra Townie Original 7D EQ - 2016
# 1   599.99  Electra Townie Original 7D EQ - Women's - 2016
# 2  3098.00                          Surly Straggler - 2016
# 3  2899.99                        Trek Fuel EX 8 29 - 2016
# 4  3599.98           Trek Remedy 29 Carbon Frameset - 2016
#
#          category_name brand_name        store_name        sales_rep
# 0    Cruisers Bicycles    Electra  Santa Cruz Bikes  Mireya Copeland
# ...

# %%
df.isnull().sum()
# Out:
# order_id         0
# customers        0
# city             0
# state            0
# order_date       0
# total_units      0
# revenue          0
# product_name     0
# category_name    0
# brand_name       0
# store_name       0
# sales_rep        0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.drop_duplicates(inplace = True)

# %%
df.dtypes
# Out:
# order_id           int64
# customers         object
# city              object
# state             object
# order_date        object
# total_units        int64
# revenue          float64
# product_name      object
# category_name     object
# brand_name        object
# store_name        object
# sales_rep         object
# dtype: object

# %%
df.describe()
# Out:
#           order_id  total_units       revenue
# count  4722.000000  4722.000000   4722.000000
# mean    821.265354     1.498941   1816.812554
# std     465.152168     0.500052   2228.160984
# min       1.000000     1.000000     89.990000
# 25%     423.250000     1.000000    539.980000
# 50%     828.500000     1.000000    939.980000
# 75%    1226.000000     2.000000   1999.980000
# max    1615.000000     2.000000  23999.980000

# %%
print(df.describe(include = None))
# Out:
#           order_id  total_units       revenue
# count  4722.000000  4722.000000   4722.000000
# mean    821.265354     1.498941   1816.812554
# std     465.152168     0.500052   2228.160984
# min       1.000000     1.000000     89.990000
# 25%     423.250000     1.000000    539.980000
# 50%     828.500000     1.000000    939.980000
# 75%    1226.000000     2.000000   1999.980000
# max    1615.000000     2.000000  23999.980000

# %%
num_columns = df.select_dtypes(include = ['float64','int64']).columns

# %%
df
# Out:
#       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28-11-2018
# 4718      1614      Dorthey Jackson     Houston    TX  28-11-2018
# 4719      1615         Sarita Parks      Forney    TX  28-12-2018
# 4720      1615         Sarita Parks      Forney    TX  28-12-2018
# 4721      1615         Sarita Parks      Forney    TX  28-12-2018
#
#       total_units  revenue                                    product_name  \
# 0               2  1199.98            Electra Townie Original 7D EQ - 2016
# ...

# %%
pip install seaborn --upgrade
# Out:
# Requirement already up-to-date: seaborn in c:\users\acer\anaconda3\lib\site-packages (0.12.2)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
for col in num_columns:
    plt.figure(figsize=(10,6))
    sns.histplot(df[col],kde=True)
    plt.show()

# %%
cat_columns = df.select_dtypes(include = ['object']).columns

# %%
cat_columns
# Out:
# Index(['customers', 'city', 'state', 'order_date', 'product_name',
#        'category_name', 'brand_name', 'store_name', 'sales_rep'],
#       dtype='object')

# %%
for col in cat_columns:
    plt.figure(figsize = (10,6))
    sns.countplot(y=col,data=df)
    plt.title('f count plot of {col}')
    plt.show()

# %%
for col in num_columns:
    if col != 'revenu s':  # Assuming 'sales' is a target variable
        plt.figure(figsize=(10, 6))
        sns.scatterplot(x=df[col], y=df['revenue'])
        plt.title(f'Revenue vs {col}')
        plt.show()
        
# for num in num_columns:
#     if col != 'sales':
#         plt.figure(figsize = (10,6))
#         sns.scatterplot(x=df[col], y=df['sales'])
#         plt.title('f sales vs {col}')
#         plt.show()

# %%
plt.figure(figsize=(12,8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix,annot = True, cmap = 'coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(df[num_columns])
plt.show()

# %%
for col in num_columns:
    plt.figure(figsize=(10,6))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
    plt.show()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       order_id            customers        city state  order_date  \
# 0            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 1            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 2            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 3            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# 4            1  Johnathan Velazquez  Pleasanton    CA    1-1-2016
# ...        ...                  ...         ...   ...         ...
# 4717      1614      Dorthey Jackson     Houston    TX  28-11-2018
# 4718      1614      Dorthey Jackson     Houston    TX  28-11-2018
# 4719      1615         Sarita Parks      Forney    TX  28-12-2018
# 4720      1615         Sarita Parks      Forney    TX  28-12-2018
# 4721      1615         Sarita Parks      Forney    TX  28-12-2018
#
#       total_units  revenue                                    product_name  \
# ...

# %%
if 'revenue' in df.columns and 'sub_category' in df.columns:
    plt.figure(figsize=(14, 10))
    pivot_table = df.pivot_table(index='category', columns='sub_category', values='revenue', aggfunc='sum')
    sns.heatmap(pivot_table, annot=True, fmt=".1f", cmap='coolwarm')
    plt.title('Heatmap of Sales by Category and Sub-Category')
    plt.show()

# %%
pip install seaborn --upgrade
# Out:
# Requirement already up-to-date: seaborn in c:\users\acer\anaconda3\lib\site-packages (0.12.2)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
if 'revenue' in df.columns and 'sub_category' in df.columns:
    plt.figure(figsize=(14, 10))
    pivot_table = df.pivot_table(index='category', columns='sub_category', values='revenue', aggfunc='sum')
    sns.heatmap(pivot_table, annot=True, fmt=".1f", cmap='coolwarm')
    plt.title('Heatmap of Sales by Category and Sub-Category')
    plt.show()
